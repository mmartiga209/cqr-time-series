# %%
# We install darts
# !pip install u8darts[torch] --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.6/200.6 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.1/823.1 kB 30.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.4/354.4 kB 22.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 71.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.8/285.8 kB 19.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 kB 50.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 7.4 MB/s eta 0:00:00

# %%
# Let's scale and store all the train data for the models
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
# We have to properly select a dataset for testing
from google.colab import drive
drive.mount('/content/drive')

# Google Colab
#file_path = "/content/drive/MyDrive/Colab Notebooks/TFG/data/01_datasets/train_test/train.csv"
file_path = "/content/drive/MyDrive/Colab Notebooks/TFG/data/01_datasets/train_test_reduced/train_reduced.csv"   # We will scale the new version of the dataset

df = pd.read_csv(file_path, low_memory=False)

df['Date'] = pd.to_datetime(df['Date'])
# Out:
# Mounted at /content/drive

# %%
df
# Out:
#                           id       Date  District       Use  Number of meters  \
# 0        0801501001_Badalona 2022-01-01         1  Domestic               250
# 1        0801501001_Badalona 2022-01-02         1  Domestic               251
# 2        0801501001_Badalona 2022-01-03         1  Domestic               251
# 3        0801501001_Badalona 2022-01-04         1  Domestic               251
# 4        0801501001_Badalona 2022-01-05         1  Domestic               251
# ...                      ...        ...       ...       ...               ...
# 605895  0819403001_Barcelona 2023-12-27         3  Domestic                41
# 605896  0819403001_Barcelona 2023-12-28         3  Domestic                41
# 605897  0819403001_Barcelona 2023-12-29         3  Domestic                41
# 605898  0819403001_Barcelona 2023-12-30         3  Domestic                41
# 605899  0819403001_Barcelona 2023-12-31         3  Domestic                41
#
#         Accumulated consumption (L/day)  Consumption per meter  Year  Month
# 0                                 16242                  64.97  2022      1
# 1                                 17477                  69.63  2022      1
# 2                                 16540                  65.90  2022      1
# 3                                 17153                  68.34  2022      1
# 4                                 18619                  74.18  2022      1
# ...                                 ...                    ...   ...    ...
# 605895                              254                   6.20  2023     12
# 605896                              246                   6.00  2023     12
# 605897                              229                   5.59  2023     12
# 605898                              258                   6.29  2023     12
# 605899                              298                   7.27  2023     12
#
# [605900 rows x 9 columns]

# %%
# Initialize empty DataFrames
train_df = pd.DataFrame()
val_df = pd.DataFrame()
calib_test_df = pd.DataFrame()

# Loop through each unique id and split
for meter_id in df['id'].unique():
    df_id = df[df['id'] == meter_id].sort_values('Date')

    train_part = df_id.iloc[:365]
    val_part = df_id.iloc[365:485]
    calib_test_part = df_id.iloc[485:]

    # Append to overall DataFrames
    train_df = pd.concat([train_df, train_part])
    val_df = pd.concat([val_df, val_part])
    calib_test_df = pd.concat([calib_test_df, calib_test_part])

# Print first and last dates for each split
print("Train set:")
print(f"Start: {train_df['Date'].min()}, End: {train_df['Date'].max()}")
print("\nValidation set:")
print(f"Start: {val_df['Date'].min()}, End: {val_df['Date'].max()}")
print("\nCalibration and test set:")
print(f"Start: {calib_test_df['Date'].min()}, End: {calib_test_df['Date'].max()}")
# Out:
# Train set:
# Start: 2022-01-01 00:00:00, End: 2022-12-31 00:00:00
#
# Validation set:
# Start: 2023-01-01 00:00:00, End: 2023-04-30 00:00:00
#
# Calibration and test set:
# Start: 2023-05-01 00:00:00, End: 2023-12-31 00:00:00

# %%
from darts.dataprocessing.transformers import Scaler
from darts import TimeSeries
import pandas as pd
import joblib

# We make sure date is in datetime format
for sub_df in [train_df, val_df]:
    sub_df['Date'] = pd.to_datetime(sub_df['Date'])

# Initialize dicts to hold scaled series and scalers
scaled_train_series = {}
scaled_val_series = {}
scalers = {}
i = 1

# Loop over each unique id
for meter_id in df['id'].unique():
    # Get train set for this id
    train_id_df = train_df[train_df['id'] == meter_id].sort_values('Date')

    # Convert to TimeSeries
    train_series = TimeSeries.from_dataframe(train_id_df, time_col='Date', value_cols='Consumption per meter')

    # Get validation set for this id
    val_id_df = val_df[val_df['id'] == meter_id].sort_values('Date')
    val_series = TimeSeries.from_dataframe(val_id_df, time_col='Date', value_cols='Consumption per meter')

    # Initialize scaler and fit on train
    # WE CAN USE THE MIN-MAX SCALER (Default Scaler between 0 and 1)
    scaler = Scaler()
    scaler.fit(train_series)

    # OR WE CAN USE THE STANDARD SCALER
    #scaler = Scaler(scaler=StandardScaler())
    #scaler.fit(train_series)

    # OR WE CAN USE THE MIN-MAX BETWEEN 1 AND 2
    #scaler = Scaler(scaler=MinMaxScaler(feature_range=(1, 2)))
    #scaler.fit(train_series)

    # Transform the series
    train_scaled = scaler.transform(train_series)
    val_scaled = scaler.transform(val_series)

    # Store results
    scaled_train_series[meter_id] = train_scaled
    scaled_val_series[meter_id] = val_scaled
    scalers[meter_id] = scaler

    # Print quick summary for progress
    print(f"Processed meter: {i}/{908}")
    i = i+1
# Out:
# Processed meter: 1/908
# Processed meter: 2/908
# Processed meter: 3/908
# Processed meter: 4/908
# Processed meter: 5/908
# Processed meter: 6/908
# Processed meter: 7/908
# Processed meter: 8/908
# Processed meter: 9/908
# Processed meter: 10/908
# Processed meter: 11/908
# Processed meter: 12/908
# Processed meter: 13/908
# Processed meter: 14/908
# Processed meter: 15/908
# Processed meter: 16/908
# Processed meter: 17/908
# Processed meter: 18/908
# Processed meter: 19/908
# Processed meter: 20/908
# Processed meter: 21/908
# Processed meter: 22/908
# Processed meter: 23/908
# Processed meter: 24/908
# Processed meter: 25/908
# Processed meter: 26/908
# Processed meter: 27/908
# Processed meter: 28/908
# Processed meter: 29/908
# Processed meter: 30/908
# Processed meter: 31/908
# Processed meter: 32/908
# Processed meter: 33/908
# Processed meter: 34/908
# Processed meter: 35/908
# Processed meter: 36/908
# Processed meter: 37/908
# Processed meter: 38/908
# Processed meter: 39/908
# Processed meter: 40/908
# Processed meter: 41/908
# Processed meter: 42/908
# Processed meter: 43/908
# Processed meter: 44/908
# Processed meter: 45/908
# Processed meter: 46/908
# Processed meter: 47/908
# Processed meter: 48/908
# Processed meter: 49/908
# Processed meter: 50/908
# Processed meter: 51/908
# Processed meter: 52/908
# Processed meter: 53/908
# Processed meter: 54/908
# Processed meter: 55/908
# Processed meter: 56/908
# Processed meter: 57/908
# Processed meter: 58/908
# Processed meter: 59/908
# Processed meter: 60/908
# Processed meter: 61/908
# Processed meter: 62/908
# Processed meter: 63/908
# Processed meter: 64/908
# Processed meter: 65/908
# Processed meter: 66/908
# Processed meter: 67/908
# Processed meter: 68/908
# Processed meter: 69/908
# Processed meter: 70/908
# Processed meter: 71/908
# Processed meter: 72/908
# Processed meter: 73/908
# Processed meter: 74/908
# Processed meter: 75/908
# Processed meter: 76/908
# Processed meter: 77/908
# Processed meter: 78/908
# Processed meter: 79/908
# Processed meter: 80/908
# Processed meter: 81/908
# Processed meter: 82/908
# Processed meter: 83/908
# Processed meter: 84/908
# Processed meter: 85/908
# Processed meter: 86/908
# Processed meter: 87/908
# Processed meter: 88/908
# Processed meter: 89/908
# Processed meter: 90/908
# Processed meter: 91/908
# Processed meter: 92/908
# Processed meter: 93/908
# Processed meter: 94/908
# Processed meter: 95/908
# Processed meter: 96/908
# Processed meter: 97/908
# Processed meter: 98/908
# Processed meter: 99/908
# Processed meter: 100/908
# Processed meter: 101/908
# Processed meter: 102/908
# Processed meter: 103/908
# Processed meter: 104/908
# Processed meter: 105/908
# Processed meter: 106/908
# Processed meter: 107/908
# Processed meter: 108/908
# Processed meter: 109/908
# Processed meter: 110/908
# Processed meter: 111/908
# Processed meter: 112/908
# Processed meter: 113/908
# Processed meter: 114/908
# Processed meter: 115/908
# Processed meter: 116/908
# Processed meter: 117/908
# Processed meter: 118/908
# Processed meter: 119/908
# Processed meter: 120/908
# Processed meter: 121/908
# Processed meter: 122/908
# Processed meter: 123/908
# Processed meter: 124/908
# Processed meter: 125/908
# Processed meter: 126/908
# Processed meter: 127/908
# Processed meter: 128/908
# Processed meter: 129/908
# Processed meter: 130/908
# Processed meter: 131/908
# Processed meter: 132/908
# Processed meter: 133/908
# Processed meter: 134/908
# Processed meter: 135/908
# Processed meter: 136/908
# Processed meter: 137/908
# Processed meter: 138/908
# Processed meter: 139/908
# Processed meter: 140/908
# Processed meter: 141/908
# Processed meter: 142/908
# Processed meter: 143/908
# Processed meter: 144/908
# Processed meter: 145/908
# Processed meter: 146/908
# Processed meter: 147/908
# Processed meter: 148/908
# Processed meter: 149/908
# Processed meter: 150/908
# Processed meter: 151/908
# Processed meter: 152/908
# Processed meter: 153/908
# Processed meter: 154/908
# Processed meter: 155/908
# Processed meter: 156/908
# Processed meter: 157/908
# Processed meter: 158/908
# Processed meter: 159/908
# Processed meter: 160/908
# Processed meter: 161/908
# Processed meter: 162/908
# Processed meter: 163/908
# Processed meter: 164/908
# Processed meter: 165/908
# Processed meter: 166/908
# Processed meter: 167/908
# Processed meter: 168/908
# Processed meter: 169/908
# Processed meter: 170/908
# Processed meter: 171/908
# Processed meter: 172/908
# Processed meter: 173/908
# Processed meter: 174/908
# Processed meter: 175/908
# Processed meter: 176/908
# Processed meter: 177/908
# Processed meter: 178/908
# Processed meter: 179/908
# Processed meter: 180/908
# Processed meter: 181/908
# Processed meter: 182/908
# Processed meter: 183/908
# Processed meter: 184/908
# Processed meter: 185/908
# Processed meter: 186/908
# Processed meter: 187/908
# Processed meter: 557/908
# Processed meter: 558/908
# Processed meter: 559/908
# Processed meter: 560/908
# Processed meter: 561/908
# Processed meter: 562/908
# Processed meter: 563/908
# Processed meter: 564/908
# Processed meter: 565/908
# Processed meter: 566/908
# Processed meter: 567/908
# Processed meter: 568/908
# Processed meter: 569/908
# Processed meter: 570/908
# Processed meter: 571/908
# Processed meter: 572/908
# Processed meter: 573/908
# Processed meter: 574/908
# Processed meter: 575/908
# Processed meter: 576/908
# Processed meter: 577/908
# Processed meter: 578/908
# Processed meter: 579/908
# Processed meter: 580/908
# Processed meter: 581/908
# Processed meter: 582/908
# Processed meter: 583/908
# Processed meter: 584/908
# Processed meter: 585/908
# Processed meter: 586/908
# Processed meter: 587/908
# Processed meter: 588/908
# Processed meter: 589/908
# Processed meter: 590/908
# Processed meter: 591/908
# Processed meter: 592/908
# Processed meter: 593/908
# Processed meter: 594/908
# Processed meter: 595/908
# Processed meter: 596/908
# Processed meter: 597/908
# Processed meter: 598/908
# Processed meter: 599/908
# Processed meter: 600/908
# Processed meter: 601/908
# Processed meter: 602/908
# Processed meter: 603/908
# Processed meter: 604/908
# Processed meter: 605/908
# Processed meter: 606/908
# Processed meter: 607/908
# Processed meter: 608/908
# Processed meter: 609/908
# Processed meter: 610/908
# Processed meter: 611/908
# Processed meter: 612/908
# Processed meter: 613/908
# Processed meter: 614/908
# Processed meter: 615/908
# Processed meter: 616/908
# Processed meter: 617/908
# Processed meter: 618/908
# Processed meter: 619/908
# Processed meter: 620/908
# Processed meter: 621/908
# Processed meter: 622/908
# Processed meter: 623/908
# Processed meter: 624/908
# Processed meter: 625/908
# Processed meter: 626/908
# Processed meter: 627/908
# Processed meter: 628/908
# Processed meter: 629/908
# Processed meter: 630/908
# Processed meter: 631/908
# Processed meter: 632/908
# Processed meter: 633/908
# Processed meter: 634/908
# Processed meter: 635/908
# Processed meter: 636/908
# Processed meter: 637/908
# Processed meter: 638/908
# Processed meter: 639/908
# Processed meter: 640/908
# Processed meter: 641/908
# Processed meter: 642/908
# Processed meter: 643/908
# Processed meter: 644/908
# Processed meter: 645/908
# Processed meter: 646/908
# Processed meter: 647/908
# Processed meter: 648/908
# Processed meter: 649/908
# Processed meter: 650/908
# Processed meter: 651/908
# Processed meter: 652/908
# Processed meter: 653/908
# Processed meter: 654/908
# Processed meter: 655/908
# Processed meter: 656/908
# Processed meter: 657/908
# Processed meter: 658/908
# Processed meter: 659/908
# Processed meter: 660/908
# Processed meter: 661/908
# Processed meter: 662/908
# Processed meter: 663/908
# Processed meter: 664/908
# Processed meter: 665/908
# Processed meter: 666/908
# Processed meter: 667/908
# Processed meter: 668/908
# Processed meter: 669/908
# Processed meter: 670/908
# Processed meter: 671/908
# Processed meter: 672/908
# Processed meter: 673/908
# Processed meter: 674/908
# Processed meter: 675/908
# Processed meter: 676/908
# Processed meter: 677/908
# Processed meter: 678/908
# Processed meter: 679/908
# Processed meter: 680/908
# Processed meter: 681/908
# Processed meter: 682/908
# Processed meter: 683/908
# Processed meter: 684/908
# Processed meter: 685/908
# Processed meter: 686/908
# Processed meter: 687/908
# Processed meter: 688/908
# Processed meter: 689/908
# Processed meter: 690/908
# Processed meter: 691/908
# Processed meter: 692/908
# Processed meter: 693/908
# Processed meter: 694/908
# Processed meter: 695/908
# Processed meter: 696/908
# Processed meter: 697/908
# Processed meter: 698/908
# Processed meter: 699/908
# Processed meter: 700/908
# Processed meter: 701/908
# Processed meter: 702/908
# Processed meter: 703/908
# Processed meter: 704/908
# Processed meter: 705/908
# Processed meter: 706/908
# Processed meter: 707/908
# Processed meter: 708/908
# Processed meter: 709/908
# Processed meter: 710/908
# Processed meter: 711/908
# Processed meter: 712/908
# Processed meter: 713/908
# Processed meter: 714/908
# Processed meter: 715/908
# Processed meter: 716/908
# Processed meter: 717/908
# Processed meter: 718/908
# Processed meter: 719/908
# Processed meter: 720/908
# Processed meter: 721/908
# Processed meter: 722/908
# Processed meter: 723/908
# Processed meter: 724/908
# Processed meter: 725/908
# Processed meter: 726/908
# Processed meter: 727/908
# Processed meter: 728/908
# Processed meter: 729/908
# Processed meter: 730/908
# Processed meter: 731/908
# Processed meter: 732/908
# Processed meter: 733/908
# Processed meter: 734/908
# Processed meter: 735/908
# Processed meter: 736/908
# Processed meter: 737/908
# Processed meter: 738/908
# Processed meter: 739/908
# Processed meter: 740/908
# Processed meter: 741/908
# Processed meter: 742/908
# Processed meter: 743/908
# Processed meter: 744/908
# Processed meter: 745/908
# Processed meter: 746/908
# Processed meter: 747/908
# Processed meter: 748/908
# Processed meter: 749/908
# Processed meter: 750/908
# Processed meter: 751/908
# Processed meter: 752/908
# Processed meter: 753/908
# Processed meter: 754/908
# Processed meter: 755/908
# Processed meter: 756/908
# Processed meter: 757/908
# Processed meter: 758/908
# Processed meter: 759/908
# Processed meter: 760/908
# Processed meter: 761/908
# Processed meter: 762/908
# Processed meter: 763/908
# Processed meter: 764/908
# Processed meter: 765/908
# Processed meter: 766/908
# Processed meter: 767/908
# Processed meter: 768/908
# Processed meter: 769/908
# Processed meter: 770/908
# Processed meter: 771/908
# Processed meter: 772/908
# Processed meter: 773/908
# Processed meter: 774/908
# Processed meter: 775/908
# Processed meter: 776/908
# Processed meter: 777/908
# Processed meter: 778/908
# Processed meter: 779/908
# Processed meter: 780/908
# Processed meter: 781/908
# Processed meter: 782/908
# Processed meter: 783/908
# Processed meter: 784/908
# Processed meter: 785/908
# Processed meter: 786/908
# Processed meter: 787/908
# Processed meter: 788/908
# Processed meter: 789/908
# Processed meter: 790/908
# Processed meter: 791/908
# Processed meter: 792/908
# Processed meter: 793/908
# Processed meter: 794/908
# Processed meter: 795/908
# Processed meter: 796/908
# Processed meter: 797/908
# Processed meter: 798/908
# Processed meter: 799/908
# Processed meter: 800/908
# Processed meter: 801/908
# Processed meter: 802/908
# Processed meter: 803/908
# Processed meter: 804/908
# Processed meter: 805/908
# Processed meter: 806/908
# Processed meter: 807/908
# Processed meter: 808/908
# Processed meter: 809/908
# Processed meter: 810/908
# Processed meter: 811/908
# Processed meter: 812/908
# Processed meter: 813/908
# Processed meter: 814/908
# Processed meter: 815/908
# Processed meter: 816/908
# Processed meter: 817/908
# Processed meter: 818/908
# Processed meter: 819/908
# Processed meter: 820/908
# Processed meter: 821/908
# Processed meter: 822/908
# Processed meter: 823/908
# Processed meter: 824/908
# Processed meter: 825/908
# Processed meter: 826/908
# Processed meter: 827/908
# Processed meter: 828/908
# Processed meter: 829/908
# Processed meter: 830/908

# %%
# Save everything in a single file
save_data = {
    'train': scaled_train_series,
    'validation': scaled_val_series,
    'scalers': scalers
}

#joblib.dump(save_data, '/content/drive/MyDrive/Colab Notebooks/TFG/data/01_datasets/train_test/scaled_train_increased_minmax.pkl')
joblib.dump(save_data, '/content/drive/MyDrive/Colab Notebooks/TFG/data/01_datasets/train_test_reduced/scaled_train_reduced.pkl')
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/TFG/data/01_datasets/train_test_reduced/scaled_train_reduced.pkl']

# %%
# Now we do the same with test
#file_path = "/content/drive/MyDrive/Colab Notebooks/TFG/data/01_datasets/train_test/test.csv"
file_path = "/content/drive/MyDrive/Colab Notebooks/TFG/data/01_datasets/train_test_reduced/test_reduced.csv"   # We will scale the new version of the dataset
df_test = pd.read_csv(file_path, low_memory=False)

df_test['Date'] = pd.to_datetime(df_test['Date'])

# %%
# Initialize empty DataFrames
train_df = pd.DataFrame()
val_df = pd.DataFrame()
calib_test_df = pd.DataFrame()

# Loop through each unique id and split
for meter_id in df_test['id'].unique():
    df_id = df_test[df_test['id'] == meter_id].sort_values('Date')

    train_part = df_id.iloc[:365]   # We simply use the same train part to make to make it coherent
    val_part = df_id.iloc[365:485]
    calib_test_part = df_id.iloc[485:]

    # Append to overall DataFrames
    train_df = pd.concat([train_df, train_part])
    val_df = pd.concat([val_df, val_part])
    calib_test_df = pd.concat([calib_test_df, calib_test_part])

# Print first and last dates for each split
print("Train set:")
print(f"Start: {train_df['Date'].min()}, End: {train_df['Date'].max()}")
print("\nBuffer set:")
print(f"Start: {val_df['Date'].min()}, End: {val_df['Date'].max()}")
print("\nTest set:")
print(f"Start: {calib_test_df['Date'].min()}, End: {calib_test_df['Date'].max()}")
# Out:
# Train set:
# Start: 2022-01-01 00:00:00, End: 2022-12-31 00:00:00
#
# Buffer set:
# Start: 2023-01-01 00:00:00, End: 2023-04-30 00:00:00
#
# Test set:
# Start: 2023-05-01 00:00:00, End: 2023-12-31 00:00:00

# %%
# We make sure date is in datetime format
for sub_df in [train_df, val_df, calib_test_df]:
    sub_df['Date'] = pd.to_datetime(sub_df['Date'])

# Initialize dicts to hold scaled series and scalers
scaled_train_series = {}
scaled_val_series = {}
scaled_calib_test_series = {}
scalers = {}
i = 1

# Loop over each unique id
for meter_id in df_test['id'].unique():
    # Get train set for this id
    train_id_df = train_df[train_df['id'] == meter_id].sort_values('Date')
    train_serie = TimeSeries.from_dataframe(train_id_df, time_col='Date', value_cols='Consumption per meter')

    # Get validation set for this id
    val_id_df = val_df[val_df['id'] == meter_id].sort_values('Date')
    val_serie = TimeSeries.from_dataframe(val_id_df, time_col='Date', value_cols='Consumption per meter')

    # Get calibration set for this id
    calib_test_id_df = calib_test_df[calib_test_df['id'] == meter_id].sort_values('Date')
    calib_test_serie = TimeSeries.from_dataframe(calib_test_id_df, time_col='Date', value_cols='Consumption per meter')

    # Initialize scaler and fit on train
    # MIN MAX SCALER between 0 and 1
    scaler = Scaler()
    scaler.fit(train_serie)

    # OR WE CAN USE THE STANDARD SCALER
    #scaler = Scaler(scaler=StandardScaler())
    #scaler.fit(train_serie)

    # OR WE CAN USE THE MIN-MAX BETWEEN 1 AND 2
    #scaler = Scaler(scaler=MinMaxScaler(feature_range=(1, 2)))
    #scaler.fit(train_series)

    # Transform the series
    train_scaled = scaler.transform(train_serie)
    val_scaled = scaler.transform(val_serie)
    calib_test_scaled = scaler.transform(calib_test_serie)

    # Store results
    scaled_train_series[meter_id] = train_scaled
    scaled_val_series[meter_id] = val_scaled
    scaled_calib_test_series[meter_id] = calib_test_scaled
    scalers[meter_id] = scaler

    # Print quick summary for progress
    print(f"Processed meter: {i}/{60}")
    i = i+1
# Out:
# Processed meter: 1/60
# Processed meter: 2/60
# Processed meter: 3/60
# Processed meter: 4/60
# Processed meter: 5/60
# Processed meter: 6/60
# Processed meter: 7/60
# Processed meter: 8/60
# Processed meter: 9/60
# Processed meter: 10/60
# Processed meter: 11/60
# Processed meter: 12/60
# Processed meter: 13/60
# Processed meter: 14/60
# Processed meter: 15/60
# Processed meter: 16/60
# Processed meter: 17/60
# Processed meter: 18/60
# Processed meter: 19/60
# Processed meter: 20/60
# Processed meter: 21/60
# Processed meter: 22/60
# Processed meter: 23/60
# Processed meter: 24/60
# Processed meter: 25/60
# Processed meter: 26/60
# Processed meter: 27/60
# Processed meter: 28/60
# Processed meter: 29/60
# Processed meter: 30/60
# Processed meter: 31/60
# Processed meter: 32/60
# Processed meter: 33/60
# Processed meter: 34/60
# Processed meter: 35/60
# Processed meter: 36/60
# Processed meter: 37/60
# Processed meter: 38/60
# Processed meter: 39/60
# Processed meter: 40/60
# Processed meter: 41/60
# Processed meter: 42/60
# Processed meter: 43/60
# Processed meter: 44/60
# Processed meter: 45/60
# Processed meter: 46/60
# Processed meter: 47/60
# Processed meter: 48/60
# Processed meter: 49/60
# Processed meter: 50/60
# Processed meter: 51/60
# Processed meter: 52/60
# Processed meter: 53/60
# Processed meter: 54/60
# Processed meter: 55/60
# Processed meter: 56/60
# Processed meter: 57/60
# Processed meter: 58/60
# Processed meter: 59/60
# Processed meter: 60/60

# %%
# Save everything in a single file
save_data = {
    'train': scaled_train_series,
    'validation': scaled_val_series,
    'calib_test': scaled_calib_test_series,
    'scalers': scalers
}

#joblib.dump(save_data, '/content/drive/MyDrive/Colab Notebooks/TFG/data/01_datasets/train_test/scaled_test_increased_minmax.pkl')
joblib.dump(save_data, '/content/drive/MyDrive/Colab Notebooks/TFG/data/01_datasets/train_test_reduced/scaled_test_reduced.pkl')
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/TFG/data/01_datasets/train_test_reduced/scaled_test_reduced.pkl']
